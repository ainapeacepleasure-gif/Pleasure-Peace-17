# %% [markdown]
# <a href="https://colab.research.google.com/github/ainapeacepleasure-gif/Pleasure-Peace-17/blob/main/ENT_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name="SAMUEL "

# %%
Age=21

# %%
Department= "Computer science"

# %%
Mathematics=75

# %%
Python=82

# %%
Statistics=68

# %%
TotalScore=225

# %%
AverageScore=75.0

# %%
HighestScore=82

# %%
LowestScore=68

# %%
Passed=True

# %%
print (Name)
# Out:
# SAMUEL

# %%
print (Age)
# Out:
# 21

# %%
print (Department )
# Out:
# Computer science

# %%
print (AverageScore)
# Out:
# 75.0

# %%
print (TotalScore)
# Out:
# 225

# %%
print (type(TotalScore))
# Out:
# <class 'int'>

# %%
print (type (HighestScore))
# Out:
# <class 'int'>

# %%
print (type(Age))
# Out:
# <class 'int'>

# %%
print (type(AverageScore))
# Out:
# <class 'float'>

# %%
print (type(Name))
# Out:
# <class 'str'>

# %%
print (type(Passed))
# Out:
# <class 'bool'>

# %%
print (Mathematics+Python+Statistics )
# Out:
# 225

# %%
print (TotalScore/Python )
# Out:
# 2.7439024390243905

# %%
print (Mathematics>Python )
# Out:
# False

# %%
print (Statistics<Python )
# Out:
# True

# %%
print (Mathematics+Python+Statistics==TotalScore)
# Out:
# True

# %%
print (Mathematics<Python)
# Out:
# True
